# %% [markdown]
# <a href="https://colab.research.google.com/github/dakotarawlings/weather_timeseries_analysis/blob/main/LSTM_wind_model/LSTM_model_building.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
@author Dakota Rawlings
@email dakota@mrl.ucsb.edu


"""

import sqlite3
import pandas as pd
from pandas import date_range

# %%
#Format a dataframe after impoting from SQL
def format_df(df_in):
    """Function for formatting a dataframe from the database file with model training NDBC data
    
    :type df_in: obj (dataframe) -  Dataframe that has been uploaded from NDBC SQL database
    :rtype dataframe - formatted dataframe
    """

    df=df_in.copy(deep=True)
    df["datetime"] = pd.to_datetime(df["datetime"])
    df=df.set_index('datetime')
    df["date"] = pd.to_datetime(df["date"])
    return df

# %%
#Establish connection with google drive directory
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#specify directories for image data

data_path="/content/gdrive/My Drive/Colab Notebooks/LSTM_weather_model/NDBC_LSTM_building_database.db"

# %%
#Query cleaned data from DB
conn = sqlite3.connect(data_path)
df_training = pd.read_sql_query("SELECT * FROM NDBC_historical_data_for_training", conn, index_col=None)

# %%
df_training=format_df(df_training)

# %%
df_training.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3902 entries, 2003-06-14 to 2014-02-17
# Data columns (total 34 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              3902 non-null   int64
#  1   WDIR               3902 non-null   float64
#  2   WSPD               3902 non-null   float64
#  3   GST                3902 non-null   float64
#  4   PRES               3902 non-null   float64
#  5   ATMP               3902 non-null   float64
#  6   WTMP               3902 non-null   float64
#  7   date               3902 non-null   datetime64[ns]
#  8   const              3902 non-null   float64
#  9   trend              3902 non-null   float64
#  10  sin(1,freq=A-DEC)  3902 non-null   float64
#  11  cos(1,freq=A-DEC)  3902 non-null   float64
#  12  sin(2,freq=A-DEC)  3902 non-null   float64
#  13  cos(2,freq=A-DEC)  3902 non-null   float64
#  14  sin(3,freq=A-DEC)  3902 non-null   float64
# ...

# %%
df_training.describe()
# Out:
#              index         WDIR         WSPD          GST         PRES  \
# count  3902.000000  3902.000000  3902.000000  3902.000000  3902.000000
# mean   1950.500000   311.182047     7.979709     9.533611  1016.817282
# std    1126.554704    38.692239     2.779244     3.350396     3.980291
# min       0.000000    86.809935     1.399323     2.076996   997.700000
# 25%     975.250000   288.000000     6.000000     7.100000  1014.100000
# 50%    1950.500000   316.000000     7.500000     8.900000  1016.300000
# 75%    2925.750000   342.000000     9.700000    11.600000  1019.300000
# max    3901.000000   360.000000    17.300000    21.000000  1032.900000
#
#               ATMP         WTMP   const        trend  sin(1,freq=A-DEC)  ...  \
# count  3902.000000  3902.000000  3902.0  3902.000000        3902.000000  ...
# mean     15.931752    16.055482     1.0  1959.500000          -0.024281  ...
# std       2.009402     2.081961     0.0  1126.554704           0.702537  ...
# ...
